# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# CROSS-VALIDATION library(train test Split library)
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error

import pickle

# removing the warning
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Bus Fare.csv")

# %%
df.head()
# Out:
#             Bus Name   Passanger Age  Distance Travel(km)  Bus fare
# 0              V.I.P              17                   22        30
# 1             Bolaka              34                   25        60
# 2  Gajipur Poribohon              19                   32        75
# 3             United              23                   30        80
# 4             Bolaka              17                   17        20

# %%
df.columns
# Out:
# Index(['Bus Name', ' Passanger Age', 'Distance Travel(km)', 'Bus fare'], dtype='str')

# %%
df = df.rename(columns={"Bus Name": "B_Name", ' Passanger Age': 'P_Age', 'Distance Travel(km)' : 'distance', 'Bus fare' : 'fare'})

# %%
df.head()
# Out:
#               B_Name  P_Age  distance  fare
# 0              V.I.P     17        22    30
# 1             Bolaka     34        25    60
# 2  Gajipur Poribohon     19        32    75
# 3             United     23        30    80
# 4             Bolaka     17        17    20

# %%
df.shape
# Out:
# (24, 4)

# %%
# Seperating the independent and dependent variable
# x = df.iloc[:, 0:-1] -> all the rows and all the columns except the last column
x = df.iloc[:, 0:-1]
# y = df.iloc[:, -1] -> all the rows and only the last column
y = df.iloc[:, -1]

# %%
# Label Encoding the categorical variable
le = LabelEncoder()
x['B_Name'] = le.fit_transform(df['B_Name'])

# %%
# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.1, random_state=22)

# %%
#lr =LinearRegression()

# %%
#model = lr.fit(xtrain, ytrain)

# %%
#model.score(xtrain, ytrain)
# Out:
# 0.5434072635317042

# %%
for i in range (115, 20):
  xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.1, random_state=i)
  lr =LinearRegression()
  model = lr.fit(xtrain, ytrain)
  print(model.score(xtrain, ytrain))

# %%
# test
bus = input
