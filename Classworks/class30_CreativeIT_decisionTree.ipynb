# %% [markdown]
# # Decision Tree
# A decision tree is a specialized type of probability tree designed to aid in making decisions
# about a particular process. It breaks down complex problems into branches, with each
# branch representing a potential outcome.
#
# **Where to use:**
# * Supervised
# * Classification
# * Entropy
# * Information Gain
# * Gini Index
#
# **Problem Dataset:**
# | Days | Outlook | Temperature | Routine | Wear Jacket? |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | Sunny | Cold | Indoor | No |
# | 2 | Sunny | Warm | Outdoor | No |
# | 3 | Cloudy | Warm | Indoor | No |
# | 4 | Sunny | Warm | Indoor | No |
# | 5 | Cloudy | Cold | Indoor | Yes |
# | 6 | Cloudy | Cold | Outdoor | Yes |
# | 7 | Sunny | Cold | Outdoor | Yes |

# %% [markdown]
# ## Part 1: Decision Tree Metrics (Formulas)
# ### Entropy
# Entropy is a measure of disorder or impurity in the given dataset. In the decision tree, messy data are split based on values of the feature vector associated with each data point.
#
# $$E(S) = \sum_{i=1}^{c} - p_i \log_2 p_i$$
#
# ### Information Gain
# Information Gain is the difference between the entropy of the parent node and the weighted average entropy of the child nodes.
#
# $$\text{Gain}(T, X) = \text{Entropy}(T) - \text{Entropy}(T, X)$$
#
# ### Gini Index
# Gini Index is a powerful measure of the randomness or the impurity or entropy in the values of a dataset aims to decrease the impurities from the root nodes.
#
# $$I_G = 1 - \sum_{j=1}^{c} p_j^2$$

# %% [markdown]
# ## Part 2: Logarithm Examples (Handwritten Notes)
# ### Integer Numbers
#
# **Method 1:**
# $$
# \begin{aligned}
# \log_2 16 &= \log_2 2^4 \\
# &= 2 \log_2 2^2 \\
# &= 2 \cdot 2 \log_2 2 \quad [\because \log_2 2 = 1] \\
# &= 4
# \end{aligned}
# $$
#
# **Alternative Method (or):**
# $$\log_2 16 = \frac{\log 16}{\log 2} = \frac{\log 2^4}{\log 2} = 4$$
#
# ---
#
# ### Fraction Numbers
#
# $$
# \begin{aligned}
# \log_2 \left(\frac{1}{16}\right) &= \frac{\log \frac{1}{16}}{\log 2} \\
# &= \frac{\log 1 - \log 16}{\log 2} \\
# &= \frac{0 - \log 2^4}{\log 2} \\
# &= \frac{-4 \log 2}{\log 2} \\
# &= -4
# \end{aligned}
# $$
