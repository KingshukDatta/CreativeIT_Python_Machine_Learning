# %%
import pandas as pd

# %%
dic = {
  "name" : ["rajib", "kawser", "toha", "chwa"] ,
  "age" :[15, 16, 14, 13],
  "id" : [191, 192, 195, 196],
  "gpa" : [9.83, 9.39, 2.58, 5.23]
}

df1 = pd.DataFrame(dic)
df1
# Out:
#      name  age   id   gpa
# 0   rajib   15  191  9.83
# 1  kawser   16  192  9.39
# 2    toha   14  195  2.58
# 3    chwa   13  196  5.23

# %%
import pandas as pd

dic1 = {
  "name" : ["rajib", "kawser", "toha", "chwa"] ,
  "profession" :[15, 16, 14, 13],
  "id" : [191, 192, 195, 196],
  "due" : [9000, 9300, 2580, 5230]
}

df2 = pd.DataFrame(dic1)
df2
# Out:
#      name  profession   id   due
# 0   rajib          15  191  9000
# 1  kawser          16  192  9300
# 2    toha          14  195  2580
# 3    chwa          13  196  5230

# %%
df2 = df2.drop(["name"], axis = 1)
df2
# Out:
#    profession   id   due
# 0          15  191  9000
# 1          16  192  9300
# 2          14  195  2580
# 3          13  196  5230

# %%
new_df = pd.merge(df1, df2, on = "id", how="inner")
new_df
# Out:
#      name  age   id   gpa  profession   due
# 0   rajib   15  191  9.83          15  9000
# 1  kawser   16  192  9.39          16  9300
# 2    toha   14  195  2.58          14  2580
# 3    chwa   13  196  5.23          13  5230

# %%
df1
# Out:
#      name  age   id   gpa
# 0   rajib   15  191  9.83
# 1  kawser   16  192  9.39
# 2    toha   14  195  2.58
# 3    chwa   13  196  5.23

# %%
import pandas as pd

dic2 = {
  "profession" :["teacher", "worker", "doctor", "engineer"],
  "id" : [191, 192, 197, 198],
  "due" : [9000, 9300, 2580, 5230]
}

df3 = pd.DataFrame(dic2)
df3
# Out:
#   profession   id   due
# 0    teacher  191  9000
# 1     worker  192  9300
# 2     doctor  197  2580
# 3   engineer  198  5230

# %%
new_df1 = pd.merge(df1, df3) # default inner join
new_df1
# Out:
#      name  age   id   gpa profession   due
# 0   rajib   15  191  9.83    teacher  9000
# 1  kawser   16  192  9.39     worker  9300

# %%
new_df1 = pd.merge(df1, df3, how="left") # left join
new_df1
# Out:
#      name  age   id   gpa profession     due
# 0   rajib   15  191  9.83    teacher  9000.0
# 1  kawser   16  192  9.39     worker  9300.0
# 2    toha   14  195  2.58        NaN     NaN
# 3    chwa   13  196  5.23        NaN     NaN

# %%
new_df1 = pd.merge(df1, df3, how="right") # right join
new_df1
# Out:
#      name   age   id   gpa profession   due
# 0   rajib  15.0  191  9.83    teacher  9000
# 1  kawser  16.0  192  9.39     worker  9300
# 2     NaN   NaN  197   NaN     doctor  2580
# 3     NaN   NaN  198   NaN   engineer  5230

# %% [markdown]
# #using "and" and "or"

# %%
new_df1["age"] == 15
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: age, dtype: bool

# %%
new_df1[new_df1['age']==15]
# Out:
#     name   age   id   gpa profession   due
# 0  rajib  15.0  191  9.83    teacher  9000

# %%
new_df1[new_df1['age']!=15]
# Out:
#      name   age   id   gpa profession   due
# 1  kawser  16.0  192  9.39     worker  9300
# 2     NaN   NaN  197   NaN     doctor  2580
# 3     NaN   NaN  198   NaN   engineer  5230

# %%
new_df1[(new_df1["age"]>15) & (new_df1["due"]>9000)]
# Out:
#      name   age   id   gpa profession   due
# 1  kawser  16.0  192  9.39     worker  9300

# %%
new_df1[(new_df1["age"]>15) | (new_df1["due"]>=9000)]
# Out:
#      name   age   id   gpa profession   due
# 0   rajib  15.0  191  9.83    teacher  9000
# 1  kawser  16.0  192  9.39     worker  9300

# %%
new_df1['profession']
# Out:
# 0     teacher
# 1      worker
# 2      doctor
# 3    engineer
# Name: profession, dtype: object

# %%
new_df1[["profession", "due"]]
# Out:
#   profession   due
# 0    teacher  9000
# 1     worker  9300
# 2     doctor  2580
# 3   engineer  5230

# %%
new_df1[(new_df1["age"]>15) | (new_df1["due"]>=9000)]["profession"]
# Out:
# 0    teacher
# 1     worker
# Name: profession, dtype: object

# %%
new_df1.to_csv("output.csv", index=False, encoding='utf-8')

# %%
df = pd.read_csv('output.csv')
df
# Out:
#      name   age   id   gpa profession   due
# 0   rajib  15.0  191  9.83    teacher  9000
# 1  kawser  16.0  192  9.39     worker  9300
# 2     NaN   NaN  197   NaN     doctor  2580
# 3     NaN   NaN  198   NaN   engineer  5230

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.to_excel('data.xlsx', index=False)

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\archive\SuperMarket Analysis.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df = pd.read_csv("C:/Users/User/Downloads/archive/SuperMarket Analysis.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# github
